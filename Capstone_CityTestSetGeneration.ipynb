# %% [markdown]
# <a href="https://colab.research.google.com/github/kquigg/Capstone557/blob/Random-Forest/Capstone_CityTestSetGeneration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Dataset

# %%
data = pd.DataFrame(pd.read_csv ('/content/drive/My Drive/EPA_SmartLocationDatabase_V3_Jan_2021_Final.csv'))
data.describe()
# Out:
#             OBJECTID       GEOID10       GEOID20        STATEFP  \
# count  220740.000000  2.207390e+05  2.207400e+05  220740.000000
# mean   110370.500000  2.870894e+11  2.870915e+11      28.623190
# std     63722.293548  1.640746e+11  1.640774e+11      16.386075
# min         1.000000  1.001020e+10  1.001020e+10       1.000000
# 25%     55185.750000  1.312100e+11  1.312100e+11      13.000000
# 50%    110370.500000  2.901900e+11  2.901900e+11      29.000000
# 75%    165555.250000  4.200350e+11  4.200350e+11      42.000000
# max    220740.000000  7.803100e+11  7.803100e+11      78.000000
#
#             COUNTYFP        TRACTCE       BLKGRPCE            CSA  \
# count  220740.000000  220740.000000  220740.000000  167709.000000
# mean       85.697449  262342.382110       2.221392     341.742661
# std        98.818946  351403.837442       1.195155     125.700068
# min         1.000000     100.000000       0.000000     104.000000
# 25%        29.000000   10303.000000       1.000000     218.000000
# 50%        61.000000   46298.000000       2.000000     361.000000
# 75%       109.000000  482503.000000       3.000000     429.000000
# max       840.000000  993000.000000       9.000000     566.000000
#
#                 CBSA      CBSA_POP  ...          D5DRI           D5DE  \
# count  203645.000000  2.207400e+05  ...  220740.000000  220740.000000
# mean    30514.836210  3.607329e+06  ...  -57326.486630  -57326.597590
# std     10979.471375  5.219925e+06  ...   49459.959391   49459.830782
# min     10100.000000  0.000000e+00  ...  -99999.000000  -99999.000000
# 25%     19740.000000  2.053030e+05  ...  -99999.000000  -99999.000000
# 50%     32820.000000  1.252890e+06  ...  -99999.000000  -99999.000000
# 75%     39300.000000  4.673634e+06  ...       0.142514       0.000354
# max     49820.000000  1.931847e+07  ...       1.000000       1.000000
#
#                D5DEI     D2A_Ranked     D2B_Ranked     D3B_Ranked  \
# count  220740.000000  220740.000000  220740.000000  220740.000000
# mean   -57326.483325      10.500000      10.500000      10.500000
# std     49459.963223       5.766294       5.766294       5.766294
# min    -99999.000000       1.000000       1.000000       1.000000
# 25%    -99999.000000       5.750000       5.750000       5.750000
# 50%    -99999.000000      10.500000      10.500000      10.500000
# 75%         0.161708      15.250000      15.250000      15.250000
# max         1.000000      20.000000      20.000000      20.000000
#
#           D4A_Ranked     NatWalkInd  Shape_Length    Shape_Area
# count  220740.000000  220740.000000  2.207400e+05  2.207400e+05
# mean        7.624884       9.541628  1.655970e+04  4.466074e+07
# std         7.812853       4.373952  3.830373e+04  6.430513e+08
# min         1.000000       1.000000  2.685713e+02  4.435890e+03
# 25%         1.000000       5.833333  3.271213e+03  4.985104e+05
# 50%         1.000000       9.166667  5.877323e+03  1.373918e+06
# 75%        16.000000      13.166667  1.596391e+04  9.413158e+06
# max        20.000000      20.000000  3.925989e+06  1.641290e+11
#
# [8 rows x 115 columns]

# %%
# find the originial shape of the dataframe
data.shape
# Out:
# (220740, 117)

# %%
data.tail(40)
# Out:
#         OBJECTID       GEOID10       GEOID20  STATEFP  COUNTYFP  TRACTCE  \
# 220700    220701  7.801100e+11  7.801100e+11       78        10   971300
# 220701    220702  7.801100e+11  7.801100e+11       78        10   970200
# 220702    220703  7.801100e+11  7.801100e+11       78        10   970500
# 220703    220704  7.801100e+11  7.801100e+11       78        10   970200
# 220704    220705  7.801100e+11  7.801100e+11       78        10   971000
# 220705    220706           NaN  7.801100e+11       78        10   990000
# 220706    220707  7.801100e+11  7.801100e+11       78        10   970100
# 220707    220708  7.801100e+11  7.801100e+11       78        10   971200
# 220708    220709  7.801100e+11  7.801100e+11       78        10   970300
# 220709    220710  7.801100e+11  7.801100e+11       78        10   970600
# 220710    220711  7.802100e+11  7.802100e+11       78        20   950200
# 220711    220712  7.803100e+11  7.803100e+11       78        30   960700
# 220712    220713  7.803100e+11  7.803100e+11       78        30   961200
# 220713    220714  7.803100e+11  7.803100e+11       78        30   960400
# 220714    220715  7.803100e+11  7.803100e+11       78        30   960300
# 220715    220716  7.802100e+11  7.802100e+11       78        20   950200
# 220716    220717  7.803100e+11  7.803100e+11       78        30   960300
# 220717    220718  7.803100e+11  7.803100e+11       78        30   960400
# 220718    220719  7.803100e+11  7.803100e+11       78        30   960500
# 220719    220720  7.803100e+11  7.803100e+11       78        30   960500
# 220720    220721  7.803100e+11  7.803100e+11       78        30   960500
# 220721    220722  7.803100e+11  7.803100e+11       78        30   960600
# 220722    220723  7.803100e+11  7.803100e+11       78        30   960600
# 220723    220724  7.803100e+11  7.803100e+11       78        30   960800
# 220724    220725  7.803100e+11  7.803100e+11       78        30   961000
# 220725    220726  7.803100e+11  7.803100e+11       78        30   961200
# 220726    220727  7.803100e+11  7.803100e+11       78        30   961100
# 220727    220728  7.803100e+11  7.803100e+11       78        30   961100
# 220728    220729  7.803100e+11  7.803100e+11       78        30   960900
# 220729    220730  7.802100e+11  7.802100e+11       78        20   950200
# 220730    220731  7.802100e+11  7.802100e+11       78        20   990000
# 220731    220732  7.802100e+11  7.802100e+11       78        20   950100
# 220732    220733  7.802100e+11  7.802100e+11       78        20   950100
# 220733    220734  7.802100e+11  7.802100e+11       78        20   950200
# 220734    220735  7.802100e+11  7.802100e+11       78        20   950100
# 220735    220736  7.803100e+11  7.803100e+11       78        30   961000
# 220736    220737  7.803100e+11  7.803100e+11       78        30   961000
# 220737    220738  7.803100e+11  7.803100e+11       78        30   961000
# 220738    220739  7.803100e+11  7.803100e+11       78        30   960700
# 220739    220740  7.803100e+11  7.803100e+11       78        30   960200
#
#         BLKGRPCE  CSA CSA_Name  CBSA  ...    D5DRI     D5DE    D5DEI  \
# 220700         1  NaN      NaN   NaN  ... -99999.0 -99999.0 -99999.0
# 220701         2  NaN      NaN   NaN  ... -99999.0 -99999.0 -99999.0
# 220702         3  NaN      NaN   NaN  ... -99999.0 -99999.0 -99999.0
# 220703         1  NaN      NaN   NaN  ... -99999.0 -99999.0 -99999.0
# 220704         1  NaN      NaN   NaN  ... -99999.0 -99999.0 -99999.0
# 220705         0  NaN      NaN   NaN  ... -99999.0 -99999.0 -99999.0
# 220706         2  NaN      NaN   NaN  ... -99999.0 -99999.0 -99999.0
# 220707         4  NaN      NaN   NaN  ... -99999.0 -99999.0 -99999.0
# 220708         3  NaN      NaN   NaN  ... -99999.0 -99999.0 -99999.0
# 220709         3  NaN      NaN   NaN  ... -99999.0 -99999.0 -99999.0
# 220710         4  NaN      NaN   NaN  ... -99999.0 -99999.0 -99999.0
# 220711         2  NaN      NaN   NaN  ... -99999.0 -99999.0 -99999.0
# 220712         1  NaN      NaN   NaN  ... -99999.0 -99999.0 -99999.0
# 220713         3  NaN      NaN   NaN  ... -99999.0 -99999.0 -99999.0
# 220714         2  NaN      NaN   NaN  ... -99999.0 -99999.0 -99999.0
# 220715         2  NaN      NaN   NaN  ... -99999.0 -99999.0 -99999.0
# 220716         1  NaN      NaN   NaN  ... -99999.0 -99999.0 -99999.0
# 220717         2  NaN      NaN   NaN  ... -99999.0 -99999.0 -99999.0
# 220718         2  NaN      NaN   NaN  ... -99999.0 -99999.0 -99999.0
# 220719         4  NaN      NaN   NaN  ... -99999.0 -99999.0 -99999.0
# 220720         3  NaN      NaN   NaN  ... -99999.0 -99999.0 -99999.0
# 220721         2  NaN      NaN   NaN  ... -99999.0 -99999.0 -99999.0
# 220722         3  NaN      NaN   NaN  ... -99999.0 -99999.0 -99999.0
# 220723         2  NaN      NaN   NaN  ... -99999.0 -99999.0 -99999.0
# 220724         1  NaN      NaN   NaN  ... -99999.0 -99999.0 -99999.0
# 220725         2  NaN      NaN   NaN  ... -99999.0 -99999.0 -99999.0
# 220726         2  NaN      NaN   NaN  ... -99999.0 -99999.0 -99999.0
# 220727         1  NaN      NaN   NaN  ... -99999.0 -99999.0 -99999.0
# 220728         2  NaN      NaN   NaN  ... -99999.0 -99999.0 -99999.0
# 220729         1  NaN      NaN   NaN  ... -99999.0 -99999.0 -99999.0
# 220730         0  NaN      NaN   NaN  ... -99999.0 -99999.0 -99999.0
# 220731         3  NaN      NaN   NaN  ... -99999.0 -99999.0 -99999.0
# 220732         2  NaN      NaN   NaN  ... -99999.0 -99999.0 -99999.0
# 220733         3  NaN      NaN   NaN  ... -99999.0 -99999.0 -99999.0
# 220734         1  NaN      NaN   NaN  ... -99999.0 -99999.0 -99999.0
# 220735         2  NaN      NaN   NaN  ... -99999.0 -99999.0 -99999.0
# 220736         3  NaN      NaN   NaN  ... -99999.0 -99999.0 -99999.0
# 220737         5  NaN      NaN   NaN  ... -99999.0 -99999.0 -99999.0
# 220738         3  NaN      NaN   NaN  ... -99999.0 -99999.0 -99999.0
# 220739         2  NaN      NaN   NaN  ... -99999.0 -99999.0 -99999.0
#
#         D2A_Ranked  D2B_Ranked  D3B_Ranked  D4A_Ranked  NatWalkInd  \
# 220700           1           1           8           1    3.333333
# 220701           1           1          14           1    5.333333
# 220702           1           1          10           1    4.000000
# 220703           1           1          17           1    6.333333
# 220704           1           1           4           1    2.000000
# 220705           1           1           1           1    1.000000
# 220706           1           1           7           1    3.000000
# 220707           1           1          13           1    5.000000
# 220708           1           1          13           1    5.000000
# 220709           1           1          17           1    6.333333
# 220710           1           1           8           1    3.333333
# 220711           1           1          11           1    4.333333
# 220712           1           1          19           1    7.000000
# 220713           1           1          10           1    4.000000
# 220714           1           1          12           1    4.666667
# 220715           1           1          12           1    4.666667
# 220716           1           1          14           1    5.333333
# 220717           1           1           9           1    3.666667
# 220718           1           1           7           1    3.000000
# 220719           1           1           8           1    3.333333
# 220720           1           1          12           1    4.666667
# 220721           1           1          11           1    4.333333
# 220722           1           1          11           1    4.333333
# 220723           1           1          12           1    4.666667
# 220724           1           1          17           1    6.333333
# 220725           1           1          20           1    7.333333
# 220726           1           1          19           1    7.000000
# 220727           1           1          13           1    5.000000
# 220728           1           1           7           1    3.000000
# 220729           1           1          12           1    4.666667
# 220730           1           1           1           1    1.000000
# 220731           1           1           4           1    2.000000
# 220732           1           1           6           1    2.666667
# 220733           1           1          18           1    6.666667
# 220734           1           1           7           1    3.000000
# 220735           1           1          20           1    7.333333
# 220736           1           1          20           1    7.333333
# 220737           1           1          20           1    7.333333
# 220738           1           1          10           1    4.000000
# 220739           1           1          12           1    4.666667
#
#          Shape_Length    Shape_Area
# 220700   18323.397510  8.029712e+06
# 220701   15224.574500  4.972788e+06
# 220702    9483.012429  3.650763e+06
# 220703    3291.041240  5.489574e+05
# 220704   27816.747680  3.102336e+07
# 220705  226686.162300  6.279305e+08
# 220706   32061.928900  2.387047e+07
# 220707    4896.555929  1.034835e+06
# 220708    7671.409913  1.965577e+06
# 220709    2610.739898  3.603123e+05
# 220710    9401.736193  4.246424e+06
# 220711    6112.441110  1.393259e+06
# 220712    3828.177862  4.970447e+05
# 220713    4653.473703  1.048797e+06
# 220714    5236.169794  6.945852e+05
# 220715    7003.927442  2.330264e+06
# 220716    4074.301650  6.241527e+05
# 220717    7885.645659  1.694159e+06
# 220718   13520.712070  6.671927e+06
# 220719   13650.520190  6.961928e+06
# 220720   12210.676360  6.422254e+06
# 220721    7011.540622  1.390328e+06
# 220722    3246.022936  5.957053e+05
# 220723    4915.172845  1.010201e+06
# 220724    2463.943413  3.434888e+05
# 220725    5696.891403  1.322843e+06
# 220726    4722.441479  5.598064e+05
# 220727    9463.916215  2.953869e+06
# 220728   17602.361930  6.170902e+06
# 220729    6355.016151  1.793284e+06
# 220730  126846.788000  1.626342e+08
# 220731   55968.290420  3.458574e+07
# 220732   27315.599450  2.644595e+07
# 220733    5499.792745  1.087226e+06
# 220734    9584.149954  4.545172e+06
# 220735    3414.446949  3.355857e+05
# 220736    2421.025608  2.924305e+05
# 220737    1955.909418  1.619395e+05
# 220738   16896.768870  1.038966e+07
# 220739    3890.488237  6.114601e+05
#
# [40 rows x 117 columns]

# %%
# bottom of the table has errors when mixing with GIS, so remove bottom 40 rows
data = data.iloc[:-40]
data.shape
# Out:
# (220700, 117)

# %%
data.tail()
# Out:
#         OBJECTID       GEOID10       GEOID20  STATEFP  COUNTYFP  TRACTCE  \
# 220695    220696  7.801100e+11  7.801100e+11       78        10   970500
# 220696    220697  7.801100e+11  7.801100e+11       78        10   971300
# 220697    220698  7.801100e+11  7.801100e+11       78        10   970100
# 220698    220699  7.801100e+11  7.801100e+11       78        10   970400
# 220699    220700  7.801100e+11  7.801100e+11       78        10   971100
#
#         BLKGRPCE  CSA CSA_Name  CBSA  ...    D5DRI     D5DE    D5DEI  \
# 220695         2  NaN      NaN   NaN  ... -99999.0 -99999.0 -99999.0
# 220696         2  NaN      NaN   NaN  ... -99999.0 -99999.0 -99999.0
# 220697         1  NaN      NaN   NaN  ... -99999.0 -99999.0 -99999.0
# 220698         2  NaN      NaN   NaN  ... -99999.0 -99999.0 -99999.0
# 220699         3  NaN      NaN   NaN  ... -99999.0 -99999.0 -99999.0
#
#         D2A_Ranked  D2B_Ranked  D3B_Ranked  D4A_Ranked  NatWalkInd  \
# 220695           1           1          15           1    5.666667
# 220696           1           1          15           1    5.666667
# 220697           1           1          10           1    4.000000
# 220698           1           1          10           1    4.000000
# 220699           1           1          20           1    7.333333
#
#         Shape_Length    Shape_Area
# 220695   5032.206718  1.222670e+06
# 220696   3168.900538  6.076288e+05
# 220697  19237.623100  7.614912e+06
# 220698   9628.634418  3.818509e+06
# 220699   5556.629977  1.457669e+06
#
# [5 rows x 117 columns]

# %% [markdown]
# # Column Names

# %%
ColumnNames = pd.DataFrame(pd.read_csv('/content/drive/My Drive/CapstoneColumnNames.csv', header = None))

# %%
ColumnNames = ColumnNames[0].str.split(r',', expand=True)
ColumnNames_First = ColumnNames[0].str.split(r'\(', expand=True)
ColumnNames_Second = ColumnNames[1].str.split(r':', expand=True)
ColumnNames = pd.concat([ColumnNames_First[0], ColumnNames_Second[1]], axis=1)
ColumnNames = ColumnNames.map(lambda x: x.strip() if isinstance(x, str) else x)

# %%
print(ColumnNames.to_string())
# Out:
#                          0                                                                                                                                 1
# 0                  GEOID10                                                                                      Census block group 12-digit FIPS code (2010)
# 1                  GEOID20                                                                                      Census block group 12-digit FIPS code (2018)
# 2                  STATEFP                                                                                                                   State FIPS code
# 3                 COUNTYFP                                                                                                                  County FIPS code
# 4                  TRACTCE                                                                                       Census tract FIPS code in which CBG resides
# 5                 BLKGRPCE                                                                                 Census block group FIPS code in which CBG resides
# 6                      CSA                                                                                              Combined Statistical Area (CSA) Code
# 7                 CSA_Name                                                                                                  Name of CSA in which CBG resides
# 8                     CBSA                                                                  FIPS for Core-Based Statistical Area (CBSA) in which CBG resides
# 9                CBSA_Name                                                                                                 Name of CBSA in which CBG resides
# 10                CBSA_POP                                                                                                        Total population in CBSA )
# 11                CBSA_EMP                                                                                                        Total employment in CBSA )
# 12                CBSA_WRK                                                                                       Total number of workers that live in CBSA )
# 13                Ac_Total                                                                                         Total geometric area (acres) of the CBG )
# 14                Ac_Water                                                                                                        Total water area (acres) )
# 15                 Ac_Land                                                                                                         Total land area (acres) )
# 16                 Ac_Unpr                                                              Total land area (acres) that is not protected from development (i.e.
# 17                  TotPop                                                                                                                        Population
# 18                 CountHU                                                                                                                     Housing units
# 19                      HH                                                                                               Households (occupied housing units)
# 20                P_WrkAge                                                                         Percent of population that is working aged 18 to 64 years
# 21                AutoOwn0                                                                             Number of households in CBG that own zero automobiles
# 22                 Pct_AO0                                                                                             Percent of zero-car households in CBG
# 23                AutoOwn1                                                                               Number of households in CBG that own one automobile
# 24                 Pct_AO1                                                                                              Percent of one-car households in CBG
# 25               AutoOwn2p                                                                      Number of households in CBG that own two or more automobiles
# 26                Pct_AO2p                                                                                         Percent of two-plus-car households in CBG
# 27                 Workers                                                                                           Count of workers in CBG (home location)
# 28             R_LowWageWk                                                                      Count of workers earning $1250/month or less (home location)
# 29             R_MedWageWk                                          Count of workers earning more than $1250/month but less than $3333/month (home location)
# 30              R_HiWageWk                                                                      Count of workers earning $3333/month or more (home location)
# 31            R_PCTLOWWAGE                                                                              Percent of low wage workers in a CBG (home location)
# 32                  TotEmp                                                                                                                  Total employment
# 33                  E5_Ret                                                                    Retail jobs within a 5-tier employment classification scheme )
# 34                  E5_Off                                                                    Office jobs within a 5-tier employment classification scheme )
# 35                  E5_Ind                                                                Industrial jobs within a 5-tier employment classification scheme )
# 36                  E5_Svc                                                                   Service jobs within a 5-tier employment classification scheme )
# 37                  E5_Ent                                                             Entertainment jobs within a 5-tier employment classification scheme )
# 38                  E8_Ret                                                                   Retail jobs within an 8-tier employment classification scheme )
# 39                  E8_off                                                                   Office jobs within an 8-tier employment classification scheme )
# 40                  E8_Ind                                                               Industrial jobs within an 8-tier employment classification scheme )
# 41                  E8_Svc                                                                  Service jobs within an 8-tier employment classification scheme )
# 42                  E8_Ent                                                            Entertainment jobs within an 8-tier employment classification scheme )
# 43                   E8_Ed                                                                Education jobs within an 8-tier employment classification scheme )
# 44                 E8_Hlth                                                              Health care jobs within an 8-tier employment classification scheme )
# 45                  E8_Pub                                                    Public administration jobs within an 8-tier employment classification scheme )
# 46             E_LowWageWk                                                                     Number of workers earning $1250/month or less (work location)
# 47             E_MedWageWk                                         Number of workers earning more than $1250/month but less than $3333/month (work location)
# 48              E_HiWageWk                                                                      Numberof workers earning $3333/month or more (work location)
# 49            E_PctLowWage                                                                      Percent LowWageWk of total #workers in a CBG (work location)
# 50                     D1A                                                                         Gross residential density (HU/acre) on unprotected land )
# 51                     D1B                                                                      Gross population density (people/acre) on unprotected land )
# 52                     D1C                                                                        Gross employment density (jobs/acre) on unprotected land )
# 53                D1C5_RET                                                        Gross retail (5-tier) employment density (jobs/acre) on unprotected land )
# 54                D1C5_OFF                                                        Gross office (5-tier) employment density (jobs/acre) on unprotected land )
# 55                D1C5_IND                                                    Gross industrial (5-tier) employment density (jobs/acre) on unprotected land )
# 56                D1C5_SVC                                                       Gross service (5-tier) employment density (jobs/acre) on unprotected land )
# 57                D1C5_ENT                                                 Gross entertainment (5-tier) employment density (jobs/acre) on unprotected land )
# 58                D1C8_RET                                                        Gross retail (8-tier) employment density (jobs/acre) on unprotected land )
# 59                D1C8_OFF                                                        Gross office (8-tier) employment density (jobs/acre) on unprotected land )
# 60                D1C8_IND                                                    Gross industrial (8-tier) employment density (jobs/acre) on unprotected land )
# 61                D1C8_SVC                                                       Gross service (8-tier) employment density (jobs/acre) on unprotected land )
# 62                D1C8_ENT                                                 Gross entertainment (8-tier) employment density (jobs/acre) on unprotected land )
# 63                 D1C8_ED                                                      Gross education(8-tier) employment density (jobs/acre) on unprotected land )
# 64               D1C8_HLTH                                                   Gross health care (8-tier) employment density (jobs/acre) on unprotected land )
# 65                D1C8_PUB                                                        Gross retail (8-tier) employment density (jobs/acre) on unprotected land )
# 66                     D1D                                                                   Gross activity density (employment + HUs) on unprotected land )
# 67                 D1_FLAG                        Flag indicating that density metrics are based on total CBG land acreage rather than unprotected acreage )
# 68                D2A_JPHH                                                                                                              Jobs per household )
# 69               D2B_E5MIX                                             5-tier employment entropy (denominator set to observed employment types in the CBG) )
# 70              D2B_E5MIXA                                         5-tier employment entropy (denominator set to the static 5 employment types in the CBG) )
# 71               D2B_E8MIX                                             8-tier employment entropy (denominator set to observed employment types in the CBG) )
# 72              D2B_E8MIXA                                         8-tier employment entropy (denominator set to the static 8 employment types in the CBG) )
# 73               D2A_EPHHM                                                                                                Employment and household entropy )
# 74              D2C_TRPMX1  Employment and Household entropy (based on vehicle trip production and trip attractions including all 5 employment categories) )
# 75              D2C_TRPMX2                                                                                     Employment and Household Entropy calculations
# 76              D2C_TRIPEQ                                                        Trip productions and trip attractions equilibrium index; the closer to one
# 77              D2R_JOBPOP                                                 Regional Diversity. Standard calculation based on population and total employment
# 78              D2R_WRKEMP                                                                                                         Household Workers per Job
# 79              D2A_WRKEMP                                                                                                         Household Workers per Job
# 80              D2C_WREMLX      Household Workers per Job Equilibrium Index; the closer to one the more balanced the resident workers and jobs in the CBG. )
# 81                     D3A                                                                                                      Total road network density )
# 82                   D3AAO                                               Network density in terms of facility miles of auto-oriented links per square mile )
# 83                   D3AMM                                                 Network density in terms of facility miles of multi-modal links per square mile )
# 84                   D3APO                                         Network density in terms of facility miles of pedestrian-oriented links per square mile )
# 85                     D3B                                                                                             Street intersection density (weighted
# 86                   D3BAO                                                    Intersection density in terms of auto-oriented intersections per square mile )
# 87                  D3BMM3                                    Intersection density in terms of multi-modal intersections having three legs per square mile )
# 88                  D3BMM4                             Intersection density in terms of multi-modal intersections having four or more legs per square mile )
# 89                  D3BPO3                            Intersection density in terms of pedestrian-oriented intersections having three legs per square mile )
# 90                  D3BPO4                     Intersection density in terms of pedestrian-oriented intersections having four or more legs per square mile )
# 91                     D4A                                                 Distance from the population-weighted centroid to nearest transit stop (meters) )
# 92                  D4B025                                                       Proportion of CBG employment within ¼ mile of fixed-guideway transit stop )
# 93                  D4B050                                                       Proportion of CBG employment within ½ mile of fixed-guideway transit stop )
# 94                     D4C                    Aggregate frequency of transit service within 0.25 miles of CBG boundary per hour during evening peak period )
# 95                     D4D                                                                    Aggregate frequency of transit service [D4c] per square mile )
# 96                     D4E                                                                         Aggregate frequency of transit service [D4c] per capita )
# 97                    D5AR                                                                                           Jobs within 45 minutes auto travel time
# 98                    D5AE                                                                         Working age population within 45 minutes auto travel time
# 99                    D5BR                                                                                             Jobs within 45-minute transit commute
# 100                   D5BE                                                                           Working age population within 45-minute transit commute
# 101                   D5CR                                                                        Proportional Accessibility to Regional Destinations - Auto
# 102                  D5CRI                                                                                                  Regional Centrality Index – Auto
# 103                   D5CE                                                                        Proportional Accessibility to Regional Destinations - Auto
# 104                  D5CEI                                                                                                  Regional Centrality Index – Auto
# 105                   D5DR                                                                     Proportional Accessibility of Regional Destinations - Transit
# 106                  D5DRI                                                                                               Regional Centrality Index – Transit
# 107                   D5DE                                                                     Proportional Accessibility of Regional Destinations - Transit
# 108                  D5DEI                                                                                               Regional Centrality Index – Transit
# 109             D2A_Ranked                                                              Quantile ranked order (1-20) of [D2a_EpHHm] from lowest to highest )
# 110             D2B_Ranked                                                             Quantile ranked order (1-20) of [D2b_E8MixA] from lowest to highest )
# 111             D3B_Ranked                                                                    Quantile ranked order (1-20) of [D3b] from lowest to highest )
# 112             D4A_Ranked                                                                                                          Quantile ranked order (1
# 113             NatWalkInd                                                                                                               Walkability Index )
# 114                 Region                                                                                   Region used to normalize vehicle miles traveled
# 115             Households                                                                                                            Number of households )
# 116              Workers_1                                                                                                               Number of workers )
# 117              Residents                                                                                                             Number of residents )
# 118                Drivers                                                                                                               Number of drivers )
# 119               Vehicles                                                                                                    Number of vehicles available )
# 120                  White                                                                                                       Number of white residents )
# 121                   Male                                                                                                        Number of male residents )
# 122                Lowwage                                                                                                 Number of of low wage residents )
# 123                Medwage                                                                                                 Number of medium wage residents )
# 124               Highwage                                                                                                   Number of high wage residents )
# 125            W_P_Lowwage                                                                                            Percent low wage workers (workplace) )
# 126            W_P_Medwage                                                                                         Percent medium wage workers (workplace) )
# 127           W_P_Highwage                                                                                        Percent of high wage workers (workplace) )
# 128               GasPrice                                                                                        2020 statewide average gas price (cents) )
# 129                 logd1a                                                                                                Log of D1a (residential density) )
# 130                 logd1c                                                                                                 Log of D1c (employment density) )
# 131               logd3aao                                                                                             Log of D3aao (auto network density) )
# 132               logd3apo                                                                                       Log of D3apo (pedestrian network density) )
# 133                 d4bo25                                                                   D4b025 (1/4 mile job accessibility to fixed guideway transit) )
# 134                d5dei_1                                                                                     D5dei (Regional centrality index - transit) )
# 135                 logd4d                                                                                       Log of D4d (frequency of transit service) )
# 136              UPTpercap                                                                                Unlinked passenger trips per capita for the CBSA )
# 137           B_C_constant                                                                                                               Constant Beta value
# 138               B_C_male                                                                                                                   Male Beta value
# 139               B_C_ld1c                                                                                                                 Logd1c Beta value
# 140            B_C_drvmveh                                                                                                 Drivers minus vehicles Beta value
# 141               B_C_ld1a                                                                                                                 Logd1a Beta value
# 142             B_C_ld3apo                                                                                                               Logd3apo Beta value
# 143               B_C_inc1                                                                                                               Low wage Beta value
# 144               B_C_gasp                                                                                                             Fuel price Beta value
# 145           B_N_constant                                                                                                               Constant Beta value
# 146               B_N_inc2                                                                                                            Medium wage Beta value
# 147               B_N_inc3                                                                                                              High wage Beta value
# 148              B_N_white                                                                                                                  White Beta value
# 149               B_N_male                                                                                                                   Male Beta value
# 150            B_N_drvmveh                                                                                                 Drivers minus vehicles Beta value
# 151               B_N_gasp                                                                                                             Fuel price Beta value
# 152               B_N_ld1a                                                                                                                 Logd1a Beta value
# 153               B_N_ld1c                                                                                                                 Logd1c Beta value
# 154             B_N_ld3aao                                                                                                               Logd3aao Beta value
# 155             B_N_ld3apo                                                                                                               Logd3apo Beta value
# 156             B_N_d4bo25                                                                                                                 D4b025 Beta value
# 157              B_N_d5dei                                                                                                                  D5dei Beta value
# 158              B_N_UPTpc                                                                                                                   UPTC Beta value
# 159         C_R_Households                                                                                                   # of households in the county )
# 160                C_R_Pop                                                                                                    # of residents in the county )
# 161            C_R_Workers                                                                                               # of workers living in the county )
# 162            C_R_Drivers                                                                                                      # of drivers in the county )
# 163           C_R_Vehicles                                                                                           # of vehicles available in the county )
# 164              C_R_White                                                                                                     Percent white in the county )
# 165               C_R_Male                                                                                                      Percent male in the county )
# 166            C_R_Lowwage                                                                                   Percent low wage workers living in the county )
# 167            C_R_Medwage                                                                                Percent medium wage workers living in the county )
# 168           C_R_Highwage                                                                                  Percent high wage workers living in the county )
# 169               C_R_DrmV                                                                                        Household drivers minus vehicles available
# 170  NonCom_VMT_Per_Worker                                                                                 Mean non-commute VMT per worker (by workplace ) )
# 171     Com_VMT_Per_Worker                                                                                     Mean commute VMT per worker (by workplace ) )
# 172         VMT_per_worker                                                                          Mean total work-related VMT per worker (by workplace ) )
# 173            VMT_tot_min                                   Minimum average daily VMT per worker per worker among all block groups within the same county )
# 174            VMT_tot_max                                              Maximum average daily VMT per worker among all block groups within the same county )
# 175            VMT_tot_avg                                             Weighted average daily VMT per worker among all block groups within the same county )
# 176         GHG_per_worker                                                    Estimated average daily GHG generated by a worker in a workplace block group )
# 177             Annual_GHG                                 Annual_GHGTotal estimated annual GHG generated by a worker (over 260 days) within a block group )
# 178           Shape_Length                                                                                                                    Shape_Length )
# 179             Shape_Area                                                                                                                      Shape_Area )
# 180               OBJECTID                                                                                                                        OBJECTID )
# 181                  Shape                                                                                                                           Shape )
# 182              SLC_score                                                                                                                       SLC_score )

# %% [markdown]
# # Cleaning

# %%
#find the number of nulls
print(data.isnull().sum().sum())
print(data.shape)
# Out:
# 141517
# (220700, 117)

# %%
# remove all rows that contain null values
data = data.dropna()
print(data.isnull().sum().sum())
print(data.shape)
# Out:
# 0
# (167265, 117)

# %%
# list all of the field names
column_list = data.columns.tolist()
print(column_list)
# Out:
# ['OBJECTID', 'GEOID10', 'GEOID20', 'STATEFP', 'COUNTYFP', 'TRACTCE', 'BLKGRPCE', 'CSA', 'CSA_Name', 'CBSA', 'CBSA_Name', 'CBSA_POP', 'CBSA_EMP', 'CBSA_WRK', 'Ac_Total', 'Ac_Water', 'Ac_Land', 'Ac_Unpr', 'TotPop', 'CountHU', 'HH', 'P_WrkAge', 'AutoOwn0', 'Pct_AO0', 'AutoOwn1', 'Pct_AO1', 'AutoOwn2p', 'Pct_AO2p', 'Workers', 'R_LowWageWk', 'R_MedWageWk', 'R_HiWageWk', 'R_PCTLOWWAGE', 'TotEmp', 'E5_Ret', 'E5_Off', 'E5_Ind', 'E5_Svc', 'E5_Ent', 'E8_Ret', 'E8_off', 'E8_Ind', 'E8_Svc', 'E8_Ent', 'E8_Ed', 'E8_Hlth', 'E8_Pub', 'E_LowWageWk', 'E_MedWageWk', 'E_HiWageWk', 'E_PctLowWage', 'D1A', 'D1B', 'D1C', 'D1C5_RET', 'D1C5_OFF', 'D1C5_IND', 'D1C5_SVC', 'D1C5_ENT', 'D1C8_RET', 'D1C8_OFF', 'D1C8_IND', 'D1C8_SVC', 'D1C8_ENT', 'D1C8_ED', 'D1C8_HLTH', 'D1C8_PUB', 'D1D', 'D1_FLAG', 'D2A_JPHH', 'D2B_E5MIX', 'D2B_E5MIXA', 'D2B_E8MIX', 'D2B_E8MIXA', 'D2A_EPHHM', 'D2C_TRPMX1', 'D2C_TRPMX2', 'D2C_TRIPEQ', 'D2R_JOBPOP', 'D2R_WRKEMP', 'D2A_WRKEMP', 'D2C_WREMLX', 'D3A', 'D3AAO', 'D3AMM', 'D3APO', 'D3B', 'D3BAO', 'D3BMM3', 'D3BMM4', 'D3BPO3', 'D3BPO4', 'D4A', 'D4B025', 'D4B050', 'D4C', 'D4D', 'D4E', 'D5AR', 'D5AE', 'D5BR', 'D5BE', 'D5CR', 'D5CRI', 'D5CE', 'D5CEI', 'D5DR', 'D5DRI', 'D5DE', 'D5DEI', 'D2A_Ranked', 'D2B_Ranked', 'D3B_Ranked', 'D4A_Ranked', 'NatWalkInd', 'Shape_Length', 'Shape_Area']

# %%
data = data.drop(columns=['GEOID10', 'GEOID20', 'STATEFP', 'COUNTYFP', 'TRACTCE', 'BLKGRPCE', 'CSA', 'CSA_Name', 'CBSA', 'CBSA_Name', 'Shape_Length', 'Shape_Area'])
data = data.set_index('OBJECTID')

# %%
print(data.head())
# Out:
#           CBSA_POP  CBSA_EMP  CBSA_WRK    Ac_Total  Ac_Water     Ac_Land  \
# OBJECTID
# 1          7189384   3545715   3364458   73.595028       0.0   73.595028
# 2          7189384   3545715   3364458  119.829909       0.0  119.829909
# 3          7189384   3545715   3364458   26.367053       0.0   26.367053
# 4          7189384   3545715   3364458  119.060687       0.0  119.060687
# 5          7189384   3545715   3364458  169.927211       0.0  169.927211
#
#              Ac_Unpr  TotPop  CountHU     HH  ...     D5CEI      D5DR  \
# OBJECTID                                      ...
# 1          73.595028    1202    460.0  423.0  ...  0.841299  0.000525
# 2         119.214200     710    409.0  409.0  ...  0.753958  0.000919
# 3          26.367050     737    365.0  329.0  ...  0.800475  0.000894
# 4         119.060687     904    384.0  384.0  ...  0.825778  0.000653
# 5         148.742920     948    343.0  343.0  ...  0.659846  0.000469
#
#              D5DRI      D5DE     D5DEI  D2A_Ranked  D2B_Ranked  D3B_Ranked  \
# OBJECTID
# 1         0.184697  0.000476  0.137707           6          14          15
# 2         0.323221  0.000801  0.231868           3          10          12
# 3         0.314628  0.000736  0.213146           1           1           7
# 4         0.229821  0.000708  0.205018          16          10          17
# 5         0.164863  0.000433  0.125296           4           7          11
#
#           D4A_Ranked  NatWalkInd
# OBJECTID
# 1                 17   14.000000
# 2                 14   10.833333
# 3                 17    8.333333
# 4                 17   15.666667
# 5                 14   10.166667
#
# [5 rows x 104 columns]

# %%
# make the walkability score its own dependent variable
walkability_given = data['NatWalkInd']
print(walkability_given.describe())
data = data.drop('NatWalkInd', axis = 1)
# Out:
# count    167265.000000
# mean         10.247944
# std           4.287695
# min           1.000000
# 25%           6.500000
# 50%          10.333333
# 75%          13.833333
# max          20.000000
# Name: NatWalkInd, dtype: float64

# %%
data.shape # should be (167265, 111)
# Out:
# (167265, 103)

# %%
# make correlation and covariance matrix
corr_matrix = data.corr()
cov_matrix = data.cov()

fig, ax = plt.subplots(figsize=(6, 4))

# Display the correlation matrix as an image
corr_matrix_image = ax.matshow(corr_matrix, cmap="coolwarm", vmin=-1, vmax=1)

# Add color bar
fig.colorbar(corr_matrix_image)

# Show the plot
plt.title("Correlation Matrix", pad=20)
plt.show()

# %% [markdown]
# Everything really red or really blue is highly correlated and should be reviewed to be removed after PCA, if PCA doesn't cover it. It is really cool how the highly correlated fields seem to form squares. This shows that the correlated columns are next to each other, which makes sense when looking at the column names.

# %% [markdown]
# # City Test Indexes

# %%
Boston_RawData = pd.DataFrame(pd.read_excel('/content/drive/My Drive/BostonTable.xls'))
Raleigh_RawData = pd.DataFrame(pd.read_excel('/content/drive/My Drive/RaleighTable.xls'))
Chicago_RawData = pd.DataFrame(pd.read_excel('/content/drive/My Drive/ChicagoTable.xls'))
BostonIndex = Boston_RawData['ID_Value']
RaleighIndex = Raleigh_RawData['ID_Value']
ChicagoIndex = Chicago_RawData['ID_Value']
total_rows_to_delete = (len(BostonIndex)+len(RaleighIndex)+len(ChicagoIndex))
print("Number of rows in Boston: ", len(BostonIndex))
print("Number of rows in Raleigh: ", len(RaleighIndex))
print("Number of rows in Chicago: ", len(ChicagoIndex))
print("Total number of rows: ", total_rows_to_delete)

#verify that the raw test sets have no null values
print("Number of null values in Boston dataset: ", Boston_RawData.isna().sum().sum())
print("Number of null values in Raleigh dataset: ", Raleigh_RawData.isna().sum().sum())
print("Number of null values in Chicago dataset: ", Chicago_RawData.isna().sum().sum())
# Out:
# Number of rows in Boston:  2628
# Number of rows in Raleigh:  646
# Number of rows in Chicago:  4758
# Total number of rows:  8032
# Number of null values in Boston dataset:  0
# Number of null values in Raleigh dataset:  0
# Number of null values in Chicago dataset:  0

# %% [markdown]
# # Build City Test Sets

# %%
data['NatWalkInd'] = walkability_given

# %%
data.head()
# Out:
#           CBSA_POP  CBSA_EMP  CBSA_WRK    Ac_Total  Ac_Water     Ac_Land  \
# OBJECTID
# 1          7189384   3545715   3364458   73.595028       0.0   73.595028
# 2          7189384   3545715   3364458  119.829909       0.0  119.829909
# 3          7189384   3545715   3364458   26.367053       0.0   26.367053
# 4          7189384   3545715   3364458  119.060687       0.0  119.060687
# 5          7189384   3545715   3364458  169.927211       0.0  169.927211
#
#              Ac_Unpr  TotPop  CountHU     HH  ...     D5CEI      D5DR  \
# OBJECTID                                      ...
# 1          73.595028    1202    460.0  423.0  ...  0.841299  0.000525
# 2         119.214200     710    409.0  409.0  ...  0.753958  0.000919
# 3          26.367050     737    365.0  329.0  ...  0.800475  0.000894
# 4         119.060687     904    384.0  384.0  ...  0.825778  0.000653
# 5         148.742920     948    343.0  343.0  ...  0.659846  0.000469
#
#              D5DRI      D5DE     D5DEI  D2A_Ranked  D2B_Ranked  D3B_Ranked  \
# OBJECTID
# 1         0.184697  0.000476  0.137707           6          14          15
# 2         0.323221  0.000801  0.231868           3          10          12
# 3         0.314628  0.000736  0.213146           1           1           7
# 4         0.229821  0.000708  0.205018          16          10          17
# 5         0.164863  0.000433  0.125296           4           7          11
#
#           D4A_Ranked  NatWalkInd
# OBJECTID
# 1                 17   14.000000
# 2                 14   10.833333
# 3                 17    8.333333
# 4                 17   15.666667
# 5                 14   10.166667
#
# [5 rows x 104 columns]

# %%
Boston_Test = data.loc[BostonIndex]
Raleigh_Test = data.loc[RaleighIndex]
Chicago_Test = data.loc[ChicagoIndex]
print("Boston Test Set Shape: ", Boston_Test.shape)
print("Raleigh Test Set Shape: ", Raleigh_Test.shape)
print("Chicago Test Set Shape: ", Chicago_Test.shape)
# Out:
# Boston Test Set Shape:  (2628, 104)
# Raleigh Test Set Shape:  (646, 104)
# Chicago Test Set Shape:  (4758, 104)

# %%
print("Data Set Shape Before Dropping City Test Sets: ", data.shape)
data = data.drop(BostonIndex)
data = data.drop(RaleighIndex)
data = data.drop(ChicagoIndex)
print("Data Set Shape After Dropping City Test Sets: ", data.shape)
# Out:
# Data Set Shape Before Dropping City Test Sets:  (167265, 104)
# Data Set Shape After Dropping City Test Sets:  (159233, 104)

# %%
walkability_given = data['NatWalkInd']
data = data.drop('NatWalkInd', axis = 1)
print("X Data Shape: ", data.shape)
print("Y Data Shape: ", walkability_given.shape)
print("Y Data Description: \n", walkability_given.describe())
# Out:
# X Data Shape:  (159233, 103)
# Y Data Shape:  (159233,)
# Y Data Description:
#  count    159233.000000
# mean         10.119862
# std           4.279203
# min           1.000000
# 25%           6.500000
# 50%          10.166667
# 75%          13.666667
# max          20.000000
# Name: NatWalkInd, dtype: float64

# %% [markdown]
# # Preprocessing

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Splitting df before any transformations to avoid leakage

X = data
y = walkability_given

np.random.seed(1)
X = X.sample(n=1000, axis=0, random_state=1)
y = y.loc[X.index]
print(X.shape)
print(y.shape)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=10)
# Out:
# (1000, 103)
# (1000,)

# %%
# Scaling data using standard scaler to 1. maintain shape of original distributions and 2. ensure all features contribute equally to PCA

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

X_train_scaled_df = pd.DataFrame(X_train_scaled, columns=X_train.columns, index=X_train.index)

# %%
# Observe scaling effects
print("Original first 2 rows:")
print(X_train.iloc[:2])
print("Scaled first 2 rows:")
print(X_train_scaled_df.iloc[:2])
# Out:
# Original first 2 rows:
#           CBSA_POP  CBSA_EMP  CBSA_WRK    Ac_Total   Ac_Water     Ac_Land  \
# OBJECTID
# 173800      645329    302655    289867  204.430031   0.000000  204.430031
# 155825    19318471   9159786   8946175  177.559635  76.804857  100.754778
#
#             Ac_Unpr  TotPop  CountHU     HH  ...      D5CE     D5CEI  \
# OBJECTID                                     ...
# 173800    204.43003     529    371.0  242.0  ...  0.002668  0.924031
# 155825     82.63146    2118    812.0  712.0  ...  0.000035  0.218241
#
#               D5DR     D5DRI      D5DE     D5DEI  D2A_Ranked  D2B_Ranked  \
# OBJECTID
# 173800    0.005673  0.544474  0.003721  0.283748          10           1
# 155825    0.000003  0.006192  0.000008  0.020042          11          12
#
#           D3B_Ranked  D4A_Ranked
# OBJECTID
# 173800            11          17
# 155825            20          20
#
# [2 rows x 103 columns]
# Scaled first 2 rows:
#           CBSA_POP  CBSA_EMP  CBSA_WRK  Ac_Total  Ac_Water   Ac_Land  \
# OBJECTID
# 173800   -0.691985 -0.678495 -0.681780 -0.115021 -0.134110 -0.112475
# 155825    2.501323  2.510626  2.539632 -0.115782 -0.052008 -0.115437
#
#            Ac_Unpr    TotPop   CountHU        HH  ...      D5CE     D5CEI  \
# OBJECTID                                          ...
# 173800   -0.102912 -1.132365 -0.748105 -1.054780  ... -0.059505  1.483344
# 155825   -0.106568  0.797044  0.653184  0.625909  ... -0.452898 -1.178827
#
#               D5DR     D5DRI      D5DE     D5DEI  D2A_Ranked  D2B_Ranked  \
# OBJECTID
# 173800    0.918324  0.918329  0.918323  0.918324   -0.020780   -1.628249
# 155825    0.918323  0.918319  0.918323  0.918319    0.152387    0.331082
#
#           D3B_Ranked  D4A_Ranked
# OBJECTID
# 173800     -0.130967     0.94227
# 155825      1.494833     1.31830
#
# [2 rows x 103 columns]

# %%
# Verify mean ≈ 0 and std ≈ 1
print("Means:", X_train_scaled_df.mean())
print("Standard deviations:", X_train_scaled_df.std())
# Out:
# Means: CBSA_POP      0.000000e+00
# CBSA_EMP     -5.773160e-17
# CBSA_WRK      5.773160e-17
# Ac_Total     -1.776357e-17
# Ac_Water      1.665335e-18
#                   ...
# D5DEI        -1.221245e-16
# D2A_Ranked    1.298961e-16
# D2B_Ranked    1.154632e-16
# D3B_Ranked    9.658940e-17
# D4A_Ranked    4.218847e-17
# Length: 103, dtype: float64
# Standard deviations: CBSA_POP      1.000626
# CBSA_EMP      1.000626
# CBSA_WRK      1.000626
# Ac_Total      1.000626
# Ac_Water      1.000626
#                 ...
# D5DEI         1.000626
# D2A_Ranked    1.000626
# D2B_Ranked    1.000626
# D3B_Ranked    1.000626
# D4A_Ranked    1.000626
# Length: 103, dtype: float64

# %%
#PCA

pca = PCA(n_components=0.95)  # n = 95% variance

X_train_pca = pca.fit_transform(X_train_scaled)
X_test_pca = pca.transform(X_test_scaled)

# %%
# Check dimensions
print("Training set shape:", X_train_pca.shape)
print("Test set shape:", X_test_pca.shape)
# Out:
# Training set shape: (800, 32)
# Test set shape: (200, 32)

# %%
# Visualize with screeplot

explained_variance_ratio = pca.explained_variance_ratio_
cumulative_variance = np.cumsum(explained_variance_ratio)

# %%
plt.figure(figsize=(8, 5))
plt.plot(range(1, len(explained_variance_ratio) + 1), cumulative_variance, marker='o', linestyle='--', label="Cumulative Variance")
plt.bar(range(1, len(explained_variance_ratio) + 1), explained_variance_ratio, alpha=0.5, label="Individual Variance")

plt.axhline(y=0.95, color='r', linestyle='--', label="95% Variance Explained")
plt.xlabel("Number of Principal Components")
plt.ylabel("Explained Variance")
plt.title("PCA Explained Variance")
plt.legend()
plt.show()

# %% [markdown]
# Conducting PCA while retaining 95% of variance gives 46 components. There is a significant drop in individual variance after ~20 components, and while the "elbow method" would suggest removing most components after this mark- my priority right now is to retain variance so I will use all 46 for now.

# %% [markdown]
# If processing time presents issues later I am comfortable exploring the effects of using 35-40 components.

# %% [markdown]
# # Additional Exploration

# %%
# Map PCA loadings to original features
pca_loadings = pd.DataFrame(
    pca.components_[:len(explained_variance_ratio)].T,
    index=X_train.columns,
    columns=[f'PC{i+1}' for i in range(len(explained_variance_ratio))]
)

print(pca_loadings.head())
# Out:
#                PC1       PC2       PC3       PC4       PC5       PC6  \
# CBSA_POP  0.086408  0.108022  0.039880  0.142451  0.094874  0.170256
# CBSA_EMP  0.086521  0.107275  0.042122  0.141869  0.096089  0.167425
# CBSA_WRK  0.086838  0.107349  0.041850  0.141719  0.097713  0.168377
# Ac_Total -0.017275 -0.047818  0.001534 -0.017834  0.077127  0.051970
# Ac_Water -0.014309 -0.047063  0.015701 -0.011897  0.052304  0.012030
#
#                PC7       PC8       PC9      PC10  ...      PC23      PC24  \
# CBSA_POP  0.130132  0.157920 -0.089451  0.077706  ... -0.034814 -0.089630
# CBSA_EMP  0.130611  0.158876 -0.088348  0.076657  ... -0.036458 -0.085576
# CBSA_WRK  0.130252  0.158047 -0.087706  0.073577  ... -0.037330 -0.083369
# Ac_Total  0.131300 -0.119494  0.432423  0.251628  ... -0.064449  0.003115
# Ac_Water  0.040214 -0.054711  0.195167  0.100252  ...  0.467556  0.027217
#
#               PC25      PC26      PC27      PC28      PC29      PC30  \
# CBSA_POP -0.053349 -0.060364 -0.026754  0.060196  0.026080  0.000509
# CBSA_EMP -0.050945 -0.055608 -0.031848  0.053509  0.022190  0.000586
# CBSA_WRK -0.051633 -0.054236 -0.030403  0.053629  0.020701  0.000445
# Ac_Total -0.061701 -0.019535  0.029592  0.016680 -0.002437  0.013408
# Ac_Water  0.573354  0.022710 -0.146826 -0.241717  0.105395 -0.109427
#
#               PC31      PC32
# CBSA_POP -0.058093  0.116337
# CBSA_EMP -0.057885  0.117387
# CBSA_WRK -0.056691  0.118813
# Ac_Total -0.001218 -0.037141
# Ac_Water -0.054783  0.086133
#
# [5 rows x 32 columns]

# %%
# Visualize loadings

plt.figure(figsize=(12, 8))
sns.heatmap(pca_loadings, cmap="coolwarm", center=0, annot=False)
plt.title("Feature Contributions to First 46 Principal Components")
plt.xlabel("Principal Components")
plt.ylabel("Original Features")
plt.show()

# %%
# Create df from scaled pca data and add back target variable. Also, index the dataframe with X_train
X_train_index = X_train.index
X_train_pca_df = pd.DataFrame(X_train_pca, index= X_train_index, columns=[f'PC{i+1}' for i in range(X_train_pca.shape[1])])

X_train_pca_df['NatWalkInd'] = y_train

# Correlation
pca_target_correlation = X_train_pca_df.corr()['NatWalkInd'].drop('NatWalkInd').sort_values(ascending=False)

# Display top 10 PCs most correlated with the target
print("Correlation between PCA components and target variable:")
print(pca_target_correlation.head(10))
# Out:
# Correlation between PCA components and target variable:
# PC2     0.604742
# PC1     0.486892
# PC3     0.439005
# PC7     0.096224
# PC26    0.068257
# PC10    0.051022
# PC8     0.046137
# PC14    0.032408
# PC29    0.028924
# PC32    0.028587
# Name: NatWalkInd, dtype: float64

# %%
X_test_index = X_test.index
X_test_pca_df = pd.DataFrame(X_test_pca, index= X_test_index, columns=[f'PC{i+1}' for i in range(X_test_pca.shape[1])])
print(X_test_pca_df.shape)
# Out:
# (200, 32)

# %%
# Find PC most positively correlated with targer
most_correlated_pc = pca_target_correlation.idxmax()

# Contributing features to top PC
top_features = pca_loadings[[most_correlated_pc]].abs().sort_values(by=most_correlated_pc, ascending=False).head(10)

print("Top features contributing to {most_correlated_pc}:")
print(top_features)
# Out:
# Top features contributing to {most_correlated_pc}:
#                  PC2
# D4A_Ranked  0.199995
# D5DEI       0.195763
# D5DRI       0.195763
# D5DR        0.195763
# D5DE        0.195763
# D4A         0.195595
# D3A         0.179531
# D3B_Ranked  0.166073
# D4D         0.156906
# D3APO       0.156254

# %%
# Find and plot two most correlated PCs against each other, colored by index value
top_2_pcs = pca_target_correlation.index[:2]


plt.figure(figsize=(8, 6))
sns.scatterplot(x=X_train_pca_df[top_2_pcs[0]], y=X_train_pca_df[top_2_pcs[1]], hue=y_train, alpha=0.6)
plt.xlabel(top_2_pcs[0])
plt.ylabel(top_2_pcs[1])
plt.title("Scatterplot of Most Correlated PCA Components vs. Target")
plt.legend(title="NatWalkInd")
plt.show()

# %% [markdown]
# ** *The following explores correlation using original features, not principal commponents* **

# %%
# Features most correlated with walkindex
feature_target_correlation = X_train.corrwith(y_train).sort_values(ascending=False)

print("Top 10 original features correlated with the target:")
print(feature_target_correlation.head(10))
# Out:
# Top 10 original features correlated with the target:
# D4A_Ranked    0.863578
# D5DRI         0.841624
# D5DEI         0.841624
# D5DE          0.841624
# D5DR          0.841624
# D4A           0.840855
# D3B_Ranked    0.750769
# D3A           0.706835
# D4C           0.696624
# D4E           0.696574
# dtype: float64
# /usr/local/lib/python3.11/dist-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /usr/local/lib/python3.11/dist-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]

# %%
# Plot most positively correlated feature against target
top_feature = feature_target_correlation.idxmax()

plt.figure(figsize=(8, 6))
sns.scatterplot(x=X_train[top_feature], y=y_train, alpha=0.6)
plt.xlabel(top_feature)
plt.ylabel("Target Variable")
plt.title(f"Scatterplot of {top_feature} vs. Target")
plt.show()

# %% [markdown]
# D4A_Ranked ( type: esriFieldTypeDouble, alias: Quantile ranked order (1,13-20) of [D4a] from lowest to highest )
#
# D4A (Distance from the population-weighted centroid to nearest transit stop (meters) )

# %%
# Scatterplots of target vs. top features (picked based on earlier pc32 results)
fig, axes = plt.subplots(2, 5, figsize=(15, 8))
axes = axes.flatten()

for i, feature in enumerate(top_features):
    sns.scatterplot(x=X_train[feature], y=y_train, alpha=0.6, ax=axes[i])
    axes[i].set_title(f"{feature} vs. Target")
    axes[i].set_xlabel(feature)
    axes[i].set_ylabel("Target")

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'PC2'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-285-2960b25d3b55> in <cell line: 0>()
#       4
#       5 for i, feature in enumerate(top_features):
# ----> 6     sns.scatterplot(x=X_train[feature], y=y_train, alpha=0.6, ax=axes[i])
#       7     axes[i].set_title(f"{feature} vs. Target")
#       8     axes[i].set_xlabel(feature)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'PC2'

# %% [markdown]
# # Random Forest Model

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
# find the tuning parameters of the random forest model and the default values.
def find_parameter(model):
  model1= model()
  print("Default Parameters:")
  for param, value in model1.get_params().items():
    print(f"{param}: {value}")
find_parameter(RandomForestRegressor)
# Out:
# Default Parameters:
# bootstrap: True
# ccp_alpha: 0.0
# criterion: squared_error
# max_depth: None
# max_features: 1.0
# max_leaf_nodes: None
# max_samples: None
# min_impurity_decrease: 0.0
# min_samples_leaf: 1
# min_samples_split: 2
# min_weight_fraction_leaf: 0.0
# monotonic_cst: None
# n_estimators: 100
# n_jobs: None
# oob_score: False
# random_state: None
# verbose: 0
# warm_start: False

# %%
X_train_preprocessed = X_train_pca_df.drop('NatWalkInd', axis=1)
X_test_preprocessed = X_test_pca_df

# %%
# find the default model scores before tuning
def default_scores(model):
  model1 = model()
  model1.fit(X_train_preprocessed, y_train)
  print("Training score:", model1.score(X_train_preprocessed, y_train))
  print("Test score:", model1.score(X_test_preprocessed, y_test))
default_scores(RandomForestRegressor)
# Out:
# Training score: 0.9877243540817331
# Test score: 0.9213240664889002

# %% [markdown]
# ## Max Depth Tuning

# %%
import time
fit_time = []
score = []
params = [5, 15, 20, 30]

for p in params:
    model = RandomForestRegressor(max_depth=p)
    start = time.time()
    model.fit(X_train_preprocessed, y_train)
    stop = time.time()
    fit_time.append(stop - start)
    score.append(model.score(X_test_preprocessed, y_test))

print("Max_depth values fit times score \n")
for p, t, s in list(zip(params, fit_time, score)):
    print(f"{p:<5} {t:>10.1f}  {s:>5.4f}")
# Out:
# Max_depth values fit times score
#
# 5            0.7  0.9043
# 15           1.3  0.9225
# 20           1.5  0.9249
# 30           1.1  0.9214

# %%
from sklearn.model_selection import GridSearchCV
model = RandomForestRegressor()
param_grid = {'max_depth': [5, 15, 20, 30]}
grid_search = GridSearchCV(model, param_grid, cv=3,
                          scoring='r2',
                          return_train_score=True,
                          refit = True)

# %%
grid_search.fit(X_train_preprocessed, y_train)
print("Test set score: {:.2f}".format(grid_search.score(X_test_preprocessed, y_test)))
# Out:
# Test set score: 0.92

# %%
best_params = grid_search.best_params_
mean_scores = grid_search.cv_results_['mean_test_score']
params = grid_search.cv_results_['params']
print("Best max_depth:", best_params['max_depth'])
print("Best score: {:.2f}".format(mean_scores.max()))
print("Standard deviation: {:.2f}".format(mean_scores.std()))
# Out:
# Best max_depth: 15
# Best score: 0.89
# Standard deviation: 0.01

# %% [markdown]
# ## N Estimators Tuning

# %%
import time
fit_time = []
score = []
params = [100, 200, 500, 1000]

for p in params:
    model = RandomForestRegressor(n_estimators=p)
    start = time.time()
    model.fit(X_train_preprocessed, y_train)
    stop = time.time()
    fit_time.append(stop - start)
    score.append(model.score(X_test_preprocessed, y_test))

print("Max_depth values fit times score \n")
for p, t, s in list(zip(params, fit_time, score)):
    print(f"{p:<5} {t:>10.1f}  {s:>5.4f}")
# Out:
# Max_depth values fit times score
#
# 100          1.4  0.9263
# 200          2.3  0.9257
# 500          7.3  0.9250
# 1000        12.7  0.9256

# %%
from sklearn.model_selection import GridSearchCV
model = RandomForestRegressor()
param_grid = {'n_estimators': [100, 200, 500]}
grid_search = GridSearchCV(model, param_grid, cv=3,
                          scoring='r2',
                          return_train_score=True,
                          refit = True)

# %%
grid_search.fit(X_train_preprocessed, y_train)
print("Test set score: {:.2f}".format(grid_search.score(X_test_preprocessed, y_test)))
# Out:
# Test set score: 0.92

# %%
best_params = grid_search.best_params_
mean_scores = grid_search.cv_results_['mean_test_score']
params = grid_search.cv_results_['params']
print("Best n_estimator:", best_params['n_estimators'])
print("Best score: {:.2f}".format(mean_scores.max()))
print("Standard deviation: {:.2f}".format(mean_scores.std()))
# Out:
# Best n_estimator: 200
# Best score: 0.89
# Standard deviation: 0.00

# %% [markdown]
# ## Best Random Forest Model

# %%
model = RandomForestRegressor(max_depth=15, n_estimators=200)
model.fit(X_train_preprocessed, y_train)
# Out:
# RandomForestRegressor(max_depth=15, n_estimators=200)

# %%
print("Training score:", model.score(X_train_preprocessed, y_train))
print("Test score:", model.score(X_test_preprocessed, y_test))
# Out:
# Training score: 0.9880038362338148
# Test score: 0.9228751258833655

# %%
from sklearn.metrics import mean_squared_error
y_train_pred = model.predict(X_train_preprocessed)
y_test_pred = model.predict(X_test_preprocessed)
mse = mean_squared_error(y_test, y_test_pred)
rmse = np.sqrt(mse)

print("Root Mean Squared Error (RMSE):", rmse)
# Out:
# Root Mean Squared Error (RMSE): 1.1868052597868946

# %%
feature_importance = model.feature_importances_
plt.figure(figsize=(10, 6))
plt.barh(X_train_preprocessed.columns, feature_importance, color='skyblue')
plt.xlabel('Importance')
plt.title('Feature Importance for Random Forest')
plt.show()

# %%
# Visualize actual vs predicted values
plt.figure(figsize=(10, 5))

# Training set
plt.subplot(1, 2, 1)
plt.scatter(y_train, y_train_pred, alpha=0.5)
plt.plot([y_train.min(), y_train.max()], [y_train.min(), y_train.max()], 'r--', lw=2)
plt.xlabel('Actual Walkability Score')
plt.ylabel('Predicted Walkability Score')
plt.title('Training Set: Actual vs Predicted')

# Test set
plt.subplot(1, 2, 2)
plt.scatter(y_test, y_test_pred, alpha=0.5)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=2)
plt.xlabel('Actual Walkability Score')
plt.ylabel('Predicted Walkability Score')
plt.title('Test Set: Actual vs Predicted')

plt.tight_layout()
plt.show()

# Feature importance through correlation with predictions
pred_importance = pd.DataFrame({
    'PC': [f'PC{i+1}' for i in range(X_train_pca.shape[1])],
    'Correlation': [np.corrcoef(X_train_pca[:, i], y_train_pred)[0, 1] for i in range(X_train_pca.shape[1])]
})
pred_importance = pred_importance.sort_values('Correlation', key=abs, ascending=False)

# visualize top 10 most important features
plt.figure(figsize=(10, 6))
plt.bar(range(10), abs(pred_importance['Correlation'][:10]))
plt.xticks(range(10), pred_importance['PC'][:10], rotation=45)
plt.xlabel('Principal Components')
plt.ylabel('Absolute Correlation with Predictions')
plt.title('Top 10 Most Important Principal Components')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor, plot_tree

# %%
find_parameter(DecisionTreeRegressor)
# Out:
# Default Parameters:
# ccp_alpha: 0.0
# criterion: squared_error
# max_depth: None
# max_features: None
# max_leaf_nodes: None
# min_impurity_decrease: 0.0
# min_samples_leaf: 1
# min_samples_split: 2
# min_weight_fraction_leaf: 0.0
# monotonic_cst: None
# random_state: None
# splitter: best

# %%
model = DecisionTreeRegressor(max_depth=3)
model.fit(X_train_preprocessed, y_train)
# Out:
# DecisionTreeRegressor(max_depth=3)

# %%
plt.figure(figsize=(12, 8))
plot_tree(model, feature_names=X_train_preprocessed.columns, filled=True)
plt.show()

# %%
feature_importances = pd.DataFrame({
    "Feature": X_train_preprocessed.columns,
    "Importance": model.feature_importances_
}).sort_values(by="Importance", ascending=False)

print(feature_importances)
# Out:
#    Feature  Importance
# 0      PC1    0.945979
# 1      PC2    0.054021
# 30    PC31    0.000000
# 29    PC30    0.000000
# 28    PC29    0.000000
# 27    PC28    0.000000
# 26    PC27    0.000000
# 25    PC26    0.000000
# 24    PC25    0.000000
# 23    PC24    0.000000
# 22    PC23    0.000000
# 21    PC22    0.000000
# 20    PC21    0.000000
# 19    PC20    0.000000
# 18    PC19    0.000000
# 17    PC18    0.000000
# 16    PC17    0.000000
# 15    PC16    0.000000
# 14    PC15    0.000000
# 13    PC14    0.000000
# 12    PC13    0.000000
# 11    PC12    0.000000
# 10    PC11    0.000000
# 9     PC10    0.000000
# 8      PC9    0.000000
# 7      PC8    0.000000
# 6      PC7    0.000000
# 5      PC6    0.000000
# 4      PC5    0.000000
# 3      PC4    0.000000
# 2      PC3    0.000000
# 31    PC32    0.000000

# %%
pc1_contributions = pca_loadings["PC2"].abs().sort_values(ascending=False)

print("Variables with the highest impact on PC2:")
print(pc1_contributions.head())
# Out:
# Variables with the highest impact on PC2:
# D4A_Ranked    0.199995
# D5DEI         0.195763
# D5DRI         0.195763
# D5DR          0.195763
# D5DE          0.195763
# Name: PC2, dtype: float64
